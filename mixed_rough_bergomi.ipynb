# %% [markdown]
# We check the code of `mixed_rough_bergomi_model.py`

# %%
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from rough_bergomi import MixedRoughBergomi


sns.set_theme("talk")
mpl.rcParams["figure.figsize"] = (8, 6)

# %% [markdown]
# ### Case1: different values of eta - call option

# %%
H = 0.1
X0 = np.log(0.235**2)
T = [1 / 12, 3 / 12, 6 / 12]
kappa = 0.2
eta1 = 0.4
eta2 = 0.7
N = 300
M = 10**5

# %%
params = {
    "eta1": eta1,
    "eta2": eta2,
    "lam": 0.2,
    "H": H,
    "X0": X0,
    "T": T[0],
    "Delta": 1 / 12,
}

# %%
mixed_rbergomi = MixedRoughBergomi(params=params)
